# %% [markdown]
# ### Importing Modules

# %%
 #import libraries
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
# Identifying missing data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %% [raw]
# I noticed several missing data points, which is a great reminder that data collected in the real-world will never be perfect.
# Missing data can impact analysis immensely, as can incorrect data .

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.describe() # Basic info related to statistics
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# ...

# %% [raw]
# Key Observation:
#     we can see in data set having much outliers having big difference in 75% and max as well as DEM
#     mean is more than 50% .so there is chances to have skewed data.
#     in some of columns having mean and std having much diff so there is possibility to data is spred very high.
#     There is missing values in column see in above info all column not having 7752 enteries.

# %% [markdown]
# ### Future Engineering:
#     Creating New columns from existing columns.

# %%
df['Date'].fillna(df['Date'].mode()[0],inplace=True) #filling missing values with mode

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
# we convert Date object column in other format for eassy calculation
df['Year']=df['Date'].dt.year 
df['Month']=df['Date'].dt.month
df['Day']=df['Date'].dt.day

# %% [markdown]
# ### Exploratory Data analysis(EDA)

# %%
corr=df.corr()
plt.figure(figsize=(16,12))
sns.heatmap(corr,annot=True,cmap='coolwarm')
# almost all points coreeleted to each others
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['DEM']) # in DEM having higher  00 entrys so there is possibility of high outlier.
# Out:
# <AxesSubplot:xlabel='DEM'>

# %%
sns.boxplot(df['LDAPS_PPT4']) # in LDAPS_PPT4 having higher  00 entrys so there is possibility of high outlier.
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT4'>

# %%
sns.boxplot(df['LDAPS_PPT3'])  #in LDAPS_PPT3 having higher  00 entrys so there is possibility of high outlier.
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT3'>

# %%
sns.boxplot(df['LDAPS_PPT1'])  #in LDAPS_PPT1 having higher  00 entrys so there is possibility of high outlier.
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT1'>

# %%
df['LDAPS_PPT4'].fillna(df['LDAPS_PPT4'].mode()[0],inplace=True) #filling missing values with mode
df['Date'].fillna(df['Date'].mode()[0],inplace=True) #filling missing values with mode
df['station'].fillna(df['station'].mode()[0],inplace=True) #filling missing values with mode
df['Next_Tmax'].fillna(df['Next_Tmax'].mode()[0],inplace=True)
df['Next_Tmin'].fillna(df['Next_Tmin'].mode()[0],inplace=True)

# %%
df['LDAPS_PPT3']=(df['LDAPS_PPT3']).replace(np.NaN,df['LDAPS_PPT3'].mean())
df['LDAPS_PPT2']=(df['LDAPS_PPT2']).replace(np.NaN,df['LDAPS_PPT2'].mean())
df['LDAPS_PPT1']=(df['LDAPS_PPT1']).replace(np.NaN,df['LDAPS_PPT1'].mean())
df['LDAPS_CC1']=(df['LDAPS_CC1']).replace(np.NaN,df['LDAPS_CC1'].mean())
df['LDAPS_CC2']=(df['LDAPS_CC2']).replace(np.NaN,df['LDAPS_CC2'].mean())
df['LDAPS_CC3']=(df['LDAPS_CC3']).replace(np.NaN,df['LDAPS_CC3'].mean())
df['LDAPS_CC4']=(df['LDAPS_CC4']).replace(np.NaN,df['LDAPS_CC4'].mean())
df['LDAPS_WS']=(df['LDAPS_WS']).replace(np.NaN,df['LDAPS_WS'].mean())
df['LDAPS_LH']=(df['LDAPS_LH']).replace(np.NaN,df['LDAPS_LH'].mean())
df['LDAPS_Tmax_lapse']=(df['LDAPS_Tmax_lapse']).replace(np.NaN,df['LDAPS_Tmax_lapse'].mean())
df['LDAPS_Tmin_lapse']=(df['LDAPS_Tmin_lapse']).replace(np.NaN,df['LDAPS_Tmin_lapse'].mean())
df['LDAPS_RHmax']=(df['LDAPS_RHmax']).replace(np.NaN,df['LDAPS_RHmax'].mean())
df['LDAPS_RHmin']=(df['LDAPS_RHmin']).replace(np.NaN,df['LDAPS_RHmin'].mean())
df['Present_Tmin']=(df['Present_Tmin']).replace(np.NaN,df['Present_Tmin'].mean())
df['Present_Tmax']=(df['Present_Tmax']).replace(np.NaN,df['Present_Tmax'].mean())
#df['']=(df['LDAPS_PPT3']).replace(np.NaN,df['LDAPS_PPT3'].mean())
#df['LDAPS_PPT3']=(df['LDAPS_PPT3']).replace(np.NaN,df['LDAPS_PPT3'].mean())
# there is much missing values so we drop this columns.

# %%
df.isnull().sum() # all missing values filling with apropriate mean and mode.
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Year                0
# Month               0
# Day                 0
# dtype: int64

# %%
sns.countplot(df['LDAPS_PPT2']) # there is much missing values so we drop this columns.
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='count'>

# %%
sns.distplot(df['LDAPS_PPT2']) # checking skewd data
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='Density'>

# %%
sns.countplot(df['LDAPS_PPT2']) # there is much missing values so we drop this columns.
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='count'>

# %%
df.drop(columns='LDAPS_PPT2',inplace=True)
df.drop(columns='Date',inplace=True)
# drop this future which is having high outlier.

# %%
#df.drop(columns='LDAPS_PPT2',inplace=True)
#df.drop(columns="LDAPS_PPT3",inplace=True)
#df.dorp(columns='LDAPS_PPT4'inplace-True)
df.drop(columns=['LDAPS_PPT1','LDAPS_PPT3','LDAPS_PPT4'],inplace=True)
# we drop this columns because this column contain zero entrys which is not useul for prediction.

# %%
df.plot(kind='box',subplots=True,layout=(10,4),figsize=(12,30)) #checking Outlier ,some of columns having high  outlier.
# Out:
# station                AxesSubplot(0.125,0.816017;0.168478x0.0639831)
# Present_Tmax        AxesSubplot(0.327174,0.816017;0.168478x0.0639831)
# Present_Tmin        AxesSubplot(0.529348,0.816017;0.168478x0.0639831)
# LDAPS_RHmin         AxesSubplot(0.731522,0.816017;0.168478x0.0639831)
# LDAPS_RHmax            AxesSubplot(0.125,0.739237;0.168478x0.0639831)
# LDAPS_Tmax_lapse    AxesSubplot(0.327174,0.739237;0.168478x0.0639831)
# LDAPS_Tmin_lapse    AxesSubplot(0.529348,0.739237;0.168478x0.0639831)
# LDAPS_WS            AxesSubplot(0.731522,0.739237;0.168478x0.0639831)
# LDAPS_LH               AxesSubplot(0.125,0.662458;0.168478x0.0639831)
# LDAPS_CC1           AxesSubplot(0.327174,0.662458;0.168478x0.0639831)
# LDAPS_CC2           AxesSubplot(0.529348,0.662458;0.168478x0.0639831)
# LDAPS_CC3           AxesSubplot(0.731522,0.662458;0.168478x0.0639831)
# LDAPS_CC4              AxesSubplot(0.125,0.585678;0.168478x0.0639831)
# ...

# %%
#Removing OUtlier
from scipy.stats import zscore 
z=np.abs(zscore(df['Next_Tmin']))
z=np.abs(zscore(df['LDAPS_WS']))

# %%
#lets see how data is distributed for every column
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in df:
                                    #  We can see that there is skewed data present in data set so need to remove skewness.
    if plotnumber<=13:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
s=np.sqrt(df['LDAPS_CC4']) #Removing of Skewness

# %%
sns.distplot(s) # After removing of skewness result shown below distplot.we got normal distribution.
# Out:
# <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Density'>

# %%
#d=np.sqrt(df['LDAPS_CC3']) # we not removing skewness because we fill missing values which is imbalance data.
#d=np.sqrt(df['LDAPS_CC2'])
#d=np.sqrt(df['LDAPS_LH'])
#d=np.sqrt(df['LDAPS_CC1'])

# %%
df.hist(figsize=(25,18))
# Out:
# array([[<AxesSubplot:title={'center':'station'}>,
#         <AxesSubplot:title={'center':'Present_Tmax'}>,
#         <AxesSubplot:title={'center':'Present_Tmin'}>,
#         <AxesSubplot:title={'center':'LDAPS_RHmin'}>,
#         <AxesSubplot:title={'center':'LDAPS_RHmax'}>],
#        [<AxesSubplot:title={'center':'LDAPS_Tmax_lapse'}>,
#         <AxesSubplot:title={'center':'LDAPS_Tmin_lapse'}>,
#         <AxesSubplot:title={'center':'LDAPS_WS'}>,
#         <AxesSubplot:title={'center':'LDAPS_LH'}>,
#         <AxesSubplot:title={'center':'LDAPS_CC1'}>],
#        [<AxesSubplot:title={'center':'LDAPS_CC2'}>,
#         <AxesSubplot:title={'center':'LDAPS_CC3'}>,
#         <AxesSubplot:title={'center':'LDAPS_CC4'}>,
#         <AxesSubplot:title={'center':'lat'}>,
#         <AxesSubplot:title={'center':'lon'}>],
#        [<AxesSubplot:title={'center':'DEM'}>,
#         <AxesSubplot:title={'center':'Slope'}>,
#         <AxesSubplot:title={'center':'Solar radiation'}>,
# ...

# %% [markdown]
# ### Train Test Split
#      separating the columns into features and target:

# %%
# Dividing the dataset into independent and dependent data before scaling
#1st we go with 'Nest_Tmax',as target veriable
x=df.drop(columns=['Next_Tmin','Next_Tmax'])
y=df.iloc[:,18:19]

# %%
# Importing necessary models
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error,mean_absolute_error

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Fitting data into Regression models-
# We now proceed to the main step of our machine learning, fitting the model and predicting the outputs.
# We fit the data into multiple Regression models to compare the performance of all models and select the best model

# %% [raw]
# ### Find the  beast Random_state use here (currently we are moving shead with Random_state 42)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=42)
print(x.shape,x_train.shape,x_test.shape)
print(y.shape,y_train.shape,y_test.shape)
# Out:
# (7752, 21) (6046, 21) (1706, 21)
# (7752, 1) (6046, 1) (1706, 1)

# %% [markdown]
# ### Standard Scaler
# The next step is to bring the data to a common scale, since there are certain columns with very small values and some columns
# with high values. This process is important as values on a similar scale allow the model to learn better.
# We use standard scaler for this process

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=scale.fit_transform(x)
x=pd.DataFrame(x)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=17)

# %%
lr=LinearRegression()

lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
lr.intercept_
# Out:
# array([30.26222287])

# %%
lr.score(x_train,y_train) #we got Model learning score is very best which is best for further Prediction
# Out:
# 0.7683799506953131

# %%
pred=lr.predict(x_test)
print(r2_score(y_test,pred))
# Out:
# 0.7592281219907775

# %%
for i in range(0,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,1)==round(r2_score(y_test,pred_test)*100,1):
        print("At random state",i,"The model perform very well")
        print("At random_state:-",i)
        print("model_Score_train :-",r2_score(y_train,pred_train)*100)
        print("r2_Score_test :-",r2_score(y_test,pred_test)*100)
# Out:
# At random state 25 The model perform very well
# At random_state:- 25
# model_Score_train :- 76.64578154236095
# r2_Score_test :- 76.64110147818788
# At random state 42 The model perform very well
# At random_state:- 42
# model_Score_train :- 76.64984654797497
# r2_Score_test :- 76.57620301705596
# At random state 60 The model perform very well
# At random_state:- 60
# model_Score_train :- 76.64230539085911
# r2_Score_test :- 76.62589628728642
# At random state 131 The model perform very well
# At random_state:- 131
# model_Score_train :- 76.63968940977051
# r2_Score_test :- 76.60590448010393
# At random state 167 The model perform very well
# At random_state:- 167
# model_Score_train :- 76.63830657354852
# r2_Score_test :- 76.60964653405419
# At random state 215 The model perform very well
# At random_state:- 215
# model_Score_train :- 76.64243739334988
# r2_Score_test :- 76.63188903590975
# At random state 235 The model perform very well
# At random_state:- 235
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Regularization:GridSearchCV:Cross Validation Score: Lasso

# %%
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

best_result=clf.best_score_
print('Best r2 score:',best_result)
# Out:
# {'alpha': 0.001, 'random_state': 0}
# Best r2 score: 0.7628182859983692

# %%
ls=Lasso(alpha=0.001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)

lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.7699074032695412

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.6844714098418474

# %% [markdown]
# ### Regularization:GridSearchCV:Cross Validation Score:-Ridge

# %%
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))} #For Ridge 
rd=Ridge()
clf=GridSearchCV(rd,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

best_result=clf.best_score_
print("Best R2 Score :",best_result)
# Out:
# {'alpha': 1, 'random_state': 0}
# Best R2 Score : 0.76281654257267

# %%
rd=Ridge(alpha=1,random_state=0)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
pred_rd=rd.predict(x_test)

rds=r2_score(y_test,pred_rd)
rds
# Out:
# 0.7699255333440804

# %%
cv_score=cross_val_score(rd,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean

# %% [markdown]
# ### KNeighborsRegressor : Model,GridSearchCV,Cross Validation Score

# %%
parameters={'n_neighbors':[5],'weights':['uniform','distance'],'algorithm':['auto','ball_tree','kd_tree','brute']}  
knr=KNeighborsRegressor()  

clf=GridSearchCV(knr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

best_result=clf.best_score_
print("Best R2 Score :",best_result)
# Out:
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}
# Best R2 Score : 0.8641487043525267

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor(algorithm='auto',n_neighbors=5,weights='distance')
knr.fit(x_train,y_train)
knr.score(x_train,y_train)
pred_decision=knr.predict(x_test)

kn=r2_score(y_test,pred_decision)
print('R2 Score :',kn*100)

krscore=cross_val_score(knr,x,y,cv=5)
kns=krscore.mean()
print("Cross val Score :",kns*100)
# Out:
# R2 Score : 86.92242413663563
# Cross val Score : 51.78270516172262

# %% [markdown]
# ### Ensemble Methods: RandomForestRegressor: Model,GridSearchCV,Cross Validation Score

# %%
from sklearn.ensemble import RandomForestRegressor

parameters={'n_estimators':[100],'max_features':['auto','sqrt','log2']}

rfr=RandomForestRegressor() 

clf=GridSearchCV(rfr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

best_result=clf.best_score_
print("Best R2 Score :",best_result)
# Out:
# {'max_features': 'sqrt', 'n_estimators': 100}
# Best R2 Score : 0.9058182087427001

# %% [raw]
# rfr=RandomForestRegressor()
# we are getting model accuracy and cross validation nearby good in other model so our model is performing extremely well.
# KNeighborsRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

rfr=RandomForestRegressor(n_estimators=100,max_features='sqrt')
rfr.fit(x_train,y_train)
rfr.score(x_train,y_train)
pred_decision=rfr.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print('R2 Score :',rfs*100)

rftscore=cross_val_score(rfr,x,y,cv=5)
rfc=rftscore.mean()
print("Cross val Score :",rfc*100)
# Out:
# R2 Score : 91.34891998027926
# Cross val Score : 67.24255289224523

# %% [markdown]
# ### Ensemble Methods: AddBoost Regressor(Boosting Sequential): Model,GridSearchCV,Cross Validation Score

# %%
from sklearn.ensemble import AdaBoostRegressor
parameters={'n_estimators':[50],'loss':['linear','square','exponential']}

adr=AdaBoostRegressor() 

clf=GridSearchCV(adr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

best_result=clf.best_score_
print("Best R2 Score :",best_result)
# Out:
# {'loss': 'square', 'n_estimators': 50}
# Best R2 Score : 0.7627160600358146

# %%
adr=AdaBoostRegressor(n_estimators=50,loss='square') 

adr.fit(x_train,y_train)
adr.score(x_train,y_train)
pred_adr=adr.predict(x_test)

adr=r2_score(y_test,pred_adr)
adr
# Out:
# 0.7616610877746102

# %% [markdown]
# ### Ensemble Methods: Gradient Boosting Regressor(Boosting Sequential): Model,GridSearchCV,Cross Validation Score

# %%
from sklearn.ensemble import GradientBoostingRegressor
parameters={'n_estimators':[100],'loss':['square_error','absolute_error','huber','quantile']}

gbr=GradientBoostingRegressor() 

clf=GridSearchCV(gbr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

best_result=clf.best_score_
print("Best R2 Score :",best_result)
# Out:
# {'loss': 'huber', 'n_estimators': 100}
# Best R2 Score : 0.8404312908859559

# %%
gbr=GradientBoostingRegressor(loss='huber') 

gbr.fit(x_train,y_train)
gbr.score(x_train,y_train)
pred_gbr=gbr.predict(x_test)

gbr=r2_score(y_test,pred_gbr)
gbr
# Out:
# 0.8502785852278971

# %% [raw]
#  rfr=RandomForestRegressor()
#
# we are getting rfr model accuracy R2 Score 91 Cross validation Score 71 Hyperparameter tuning Grid Search CV Score 90
# which is best.so our model performing extremely well.
#
# since cross validation score model score  are almost same.we are heading with a good approach.

# %% [markdown]
# ### Saving Model

# %%
import pickle 
filename='Temperature_Forecast.pkl'
pickle.dump(rfr,open(filename,'wb'))

# %% [markdown]
# ### Conclusion:

# %%
loaded_model=pickle.load(open('Temperature_Forecast.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.9134891998027926

# %%
#we predict the maximum air temperature (Â°C)
pred=rfr.predict(x_test)
print("Predict Max Temperature",pred)
print("Actual Max Temperature",y_test)
# Out:
# Predict Max Temperature [32.515 30.895 31.188 ... 30.071 27.653 25.387]
# Actual Max Temperature       Next_Tmax
# 779        32.1
# 4406       29.2
# 3658       31.5
# 3560       28.9
# 7164       31.1
# ...         ...
# 5391       32.7
# 7728       26.9
# 5227       30.3
# 6393       28.0
# 7461       24.1
#
# [1551 rows x 1 columns]

# %% [markdown]
# ### Now we consider Next_Tmin as a target column.

# %%
x=df.drop(columns=['Next_Tmin','Next_Tmax'])
y=df.iloc[:,19:20]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=42)

# %%
lr=LinearRegression()

lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[-1.37065954e-03,  3.14155263e-02,  2.40944885e-01,
#          1.64500939e-02,  5.23436215e-03,  8.76261692e-02,
#          6.37644212e-01,  3.26719802e-02,  8.78969058e-04,
#         -5.17268891e-01,  2.38864537e-01, -2.94854162e-01,
#         -3.67009547e-02, -7.59216933e-01, -7.72497216e-01,
#         -7.44108946e-03,  2.32474984e-01,  8.38377838e-05,
#          3.39231166e-02, -7.66764323e-03,  1.22747447e-02]])

# %%
lr.intercept_
# Out:
# array([55.17839994])

# %%
lr.score(x_train,y_train)
# Out:
# 0.8257442103677594

# %%
pred=lr.predict(x_test)
print(r2_score(y_test,pred))
# Out:
# 0.841867927295149

# %% [markdown]
# ### Regularization:GridSearchCV:Cross Validation Score: Lasso

# %%
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

best_result=clf.best_score_
print('Best r2 score:',best_result)
# Out:
# {'alpha': 0.0001, 'random_state': 0}
# Best r2 score: 0.8241377704713944

# %%
ls=Lasso(alpha=0.001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)

lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.8419154730898436

# %%
# KFold Cross Validation
score=cross_val_score(ls,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.69704976 0.63421829 0.802096   0.8663461  0.848823  ]
# 0.7697066295547736
# 0.08975942120816706

# %% [markdown]
# ### Regularization:GridSearchCV:Cross Validation Score:-Ridge

# %%
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))} #For Ridge 
rd=Ridge()
clf=GridSearchCV(rd,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

best_result=clf.best_score_
print("Best R2 Score :",best_result)
# Out:
# {'alpha': 1, 'random_state': 0}
# Best R2 Score : 0.8241399826266542

# %%
rd=Ridge(alpha=1,random_state=0)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
pred_rd=rd.predict(x_test)

rds=r2_score(y_test,pred_rd)
rds
# Out:
# 0.841895747230389

# %%
# KFold Cross Validation
score=cross_val_score(rd,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.69353467 0.63395934 0.80180946 0.86648511 0.84812738]
# 0.7687831904261031
# 0.09030139776875293

# %% [markdown]
# ### KNeighborsRegressor : Model,GridSearchCV,Cross Validation Score

# %%
parameters={'n_neighbors':[5],'weights':['uniform','distance'],'algorithm':['auto','ball_tree','kd_tree','brute']}  
knr=KNeighborsRegressor()  

clf=GridSearchCV(knr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

best_result=clf.best_score_
print("Best R2 Score :",best_result)
# Out:
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}
# Best R2 Score : 0.5111750598981114

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor(algorithm='auto',n_neighbors=5,weights='distance')
knr.fit(x_train,y_train)
knr.score(x_train,y_train)
pred_decision=knr.predict(x_test)

kn=r2_score(y_test,pred_decision)
print('R2 Score :',kn*100)

krscore=cross_val_score(knr,x,y,cv=5)
kns=krscore.mean()
print("Cross val Score :",kns*100)
# Out:
# R2 Score : 55.400153488578226
# Cross val Score : 5.979728597667937

# %% [markdown]
# ### Ensemble Methods: RandomForestRegressor: Model,GridSearchCV,Cross Validation Score

# %%
from sklearn.ensemble import RandomForestRegressor

parameters={'n_estimators':[100],'max_features':['auto','sqrt','log2']}

rfr=RandomForestRegressor() 

clf=GridSearchCV(rfr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

best_result=clf.best_score_
print("Best R2 Score :",best_result)
# Out:
# {'max_features': 'log2', 'n_estimators': 100}
# Best R2 Score : 0.906530098693038

# %% [raw]
# rfr=RandomForestRegressor()
# we are getting model accuracy and cross validation nearby good in other model so our model is performing extremely well.
# KNeighborsRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

rfr=RandomForestRegressor(n_estimators=100,max_features='log2')
rfr.fit(x_train,y_train)
rfr.score(x_train,y_train)
pred_decision=rfr.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print('R2 Score :',rfs*100)

rftscore=cross_val_score(rfr,x,y,cv=5)
rfc=rftscore.mean()
print("Cross val Score :",rfc*100)
# Out:
# R2 Score : 92.11454257371348
# Cross val Score : 76.0263208330669

# %% [raw]
#  rfr=RandomForestRegressor()
#
# we are getting rfr model accuracy R2 Score 92 Cross validation Score 76 Hyperparameter tuning Grid Search CV Score 90
# which is best.so our model performing extremely well.
#
# since cross validation score model score  are almost same.we are heading with a good approach.

# %% [markdown]
# ### Saving Model

# %% [raw]
# import pickle
# filename='Temperature_Forecast.pkl'
# pickle.dump(rfr,open(filename,'wb'))

# %% [markdown]
# ### Conclusion:

# %%
#we predict the minimum air temperature (Â°C)
pred=rfr.predict(x_test)
print("Predict Min Temperature",pred)
print("Actual Min Temperature",y_test)
# Out:
# Predict Min Temperature [20.411 27.285 21.303 ... 23.047 24.305 24.019]
# Actual Min Temperature       Next_Tmin
# 5082       20.3
# 5597       27.5
# 1623       21.2
# 6821       25.2
# 3892       26.0
# ...         ...
# 6154       17.0
# 4239       23.8
# 7414       23.5
# 2098       24.6
# 6620       24.0
#
# [1706 rows x 1 columns]
